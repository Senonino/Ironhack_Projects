# %%
import pandas as pd
import numpy as np

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
df = pd.read_csv("weather_madrid_LEMD_1997_2015.csv", low_memory=False)

# %%
df.head()
# Out:
#         CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0  1997-1-1               7.0                4.0               2.0
# 1  1997-1-2               7.0                3.0               0.0
# 2  1997-1-3               5.0                3.0               2.0
# 3  1997-1-4               7.0                3.0              -1.0
# 4  1997-1-5               2.0                0.0              -1.0
#
#    Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# 0         5.0             3.0            2.0         100.0            95.0
# 1         6.0             3.0            0.0         100.0            92.0
# 2         5.0             1.0           -1.0         100.0            85.0
# 3        -2.0            -3.0           -4.0          86.0            63.0
# 4         2.0             0.0           -3.0         100.0            95.0
#
#     Min Humidity   Max Sea Level PressurehPa   Mean Sea Level PressurehPa  \
# ...

# %%
df.dtypes
# Out:
# CET                             object
# Max TemperatureC               float64
# Mean TemperatureC              float64
# Min TemperatureC               float64
# Dew PointC                     float64
# MeanDew PointC                 float64
# Min DewpointC                  float64
# Max Humidity                   float64
#  Mean Humidity                 float64
#  Min Humidity                  float64
#  Max Sea Level PressurehPa       int64
#  Mean Sea Level PressurehPa      int64
#  Min Sea Level PressurehPa       int64
#  Max VisibilityKm              float64
#  Mean VisibilityKm             float64
#  Min VisibilitykM              float64
#  Max Wind SpeedKm/h              int64
#  Mean Wind SpeedKm/h             int64
#  Max Gust SpeedKm/h            float64
# Precipitationmm                float64
#  CloudCover                    float64
#  Events                         object
# WindDirDegrees                   int64
# dtype: object

# %%
# change CET to date time format
df["CET"] = pd.to_datetime(df["CET"])
df = df.reset_index(drop=True)

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['CET', 'Max TemperatureC', 'Mean TemperatureC', 'Min TemperatureC',
#        'Dew PointC', 'MeanDew PointC', 'Min DewpointC', 'Max Humidity',
#        'Mean Humidity', 'Min Humidity', 'Max Sea Level PressurehPa',
#        'Mean Sea Level PressurehPa', 'Min Sea Level PressurehPa',
#        'Max VisibilityKm', 'Mean VisibilityKm', 'Min VisibilitykM',
#        'Max Wind SpeedKm/h', 'Mean Wind SpeedKm/h', 'Max Gust SpeedKm/h',
#        'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
# Drop the columns we don't need
columns = ["Max Gust SpeedKm/h", "Precipitationmm", "Events", "WindDirDegrees"]
df = df.drop(columns = columns, axis=1)

# %%
df.head(999)
# Out:
#            CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0   1997-01-01               7.0                4.0               2.0
# 1   1997-01-02               7.0                3.0               0.0
# 2   1997-01-03               5.0                3.0               2.0
# 3   1997-01-04               7.0                3.0              -1.0
# 4   1997-01-05               2.0                0.0              -1.0
# 5   1997-01-06               7.0                3.0               1.0
# 6   1997-01-07               2.0                0.0              -2.0
# 7   1997-01-08               8.0                4.0               1.0
# 8   1997-01-09              12.0               10.0               8.0
# 9   1997-01-10              13.0                8.0               3.0
# 10  1997-01-11              16.0               10.0               5.0
# 11  1997-01-12              17.0               10.0               3.0
# ...

# %%
df.dtypes
# Out:
# CET                           datetime64[ns]
# Max TemperatureC                     float64
# Mean TemperatureC                    float64
# Min TemperatureC                     float64
# Dew PointC                           float64
# MeanDew PointC                       float64
# Min DewpointC                        float64
# Max Humidity                         float64
# Mean Humidity                        float64
# Min Humidity                         float64
# Max Sea Level PressurehPa              int64
# Mean Sea Level PressurehPa             int64
# Min Sea Level PressurehPa              int64
# Max VisibilityKm                     float64
# Mean VisibilityKm                    float64
# Min VisibilitykM                     float64
# Max Wind SpeedKm/h                     int64
# Mean Wind SpeedKm/h                    int64
# CloudCover                           float64
# dtype: object

# %%
df = df.rename(columns={"CET": "Date"})

# %%
df = df.dropna()
df = df.reset_index(drop=True)

# %%
df["Max Humidity"] = df["Max Humidity"]/100
df["Mean Humidity"] = df["Mean Humidity"]/100
df["Min Humidity"] = df["Min Humidity"]/100

# %%
df = df.astype({"Max TemperatureC" : "int",
                "Mean TemperatureC": "int", 
                "Min TemperatureC": "int", 
                "Dew PointC": "int", 
                "MeanDew PointC": "int", 
                "Min DewpointC": "int", 
                "Max Humidity": "int", 
                "Mean Humidity": "int", 
                "Min Humidity": "int", 
                "Max Sea Level PressurehPa": "int", 
                "Mean Sea Level PressurehPa": "int", 
                "Min Sea Level PressurehPa": "int", 
                "Max VisibilityKm": "int", 
                "Mean VisibilityKm": "int",
                "Min VisibilitykM": "int", 
                "CloudCover": "int"})

# %%
df.describe()
# Out:
#        Max TemperatureC  Mean TemperatureC  Min TemperatureC   Dew PointC  \
# count       5439.000000        5439.000000       5439.000000  5439.000000
# mean          20.260526          14.409818          8.926825     8.728075
# std            8.753309           7.417457          6.553131     4.535521
# min            0.000000          -3.000000        -10.000000   -10.000000
# 25%           13.000000           8.000000          4.000000     6.000000
# 50%           19.000000          13.000000          9.000000     9.000000
# 75%           28.000000          21.000000         14.000000    12.000000
# max           41.000000          32.000000         28.000000    20.000000
#
#        MeanDew PointC  Min DewpointC  Max Humidity  Mean Humidity  \
# count     5439.000000    5439.000000   5439.000000    5439.000000
# mean         5.644420       2.195992      0.255010       0.000184
# std          4.449097       4.661137      0.435907       0.013559
# ...

# %%
df.dtypes
# Out:
# Date                          datetime64[ns]
# Max TemperatureC                       int32
# Mean TemperatureC                      int32
# Min TemperatureC                       int32
# Dew PointC                             int32
# MeanDew PointC                         int32
# Min DewpointC                          int32
# Max Humidity                           int32
# Mean Humidity                          int32
# Min Humidity                           int32
# Max Sea Level PressurehPa              int32
# Mean Sea Level PressurehPa             int32
# Min Sea Level PressurehPa              int32
# Max VisibilityKm                       int32
# Mean VisibilityKm                      int32
# Min VisibilitykM                       int32
# Max Wind SpeedKm/h                     int64
# Mean Wind SpeedKm/h                    int64
# CloudCover                             int32
# dtype: object

# %%
df.to_csv("Weather_Madrid_clean.csv", encoding='utf-8')
