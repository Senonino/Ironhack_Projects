# %%
import pandas as pd
import re
import datetime
import bs4
import requests 
import json

# %%
#import json file
df = pd.read_csv("Berlin_Airbnb_listings.csv", low_memory=False)

# %%
df.head(999)
# Out:
#           id                                              name  host_id  \
# 0       2015  Berlin-Mitte Value! Quiet courtyard/very central     2217
# 1       2695                Prenzlauer Berg close to Mauerpark     2986
# 2       3176                   Fabulous Flat in great Location     3718
# 3       3309                 BerlinSpot Schöneberg near KaDeWe     4108
# 4       7071                  BrightRoom with sunny greenview!    17391
# ..       ...                                               ...      ...
# 994  1111145                   apartment 4_miniloft - downtown  6099328
# 995  1114908                 room in the green heart of Berlin  6114058
# 996  1115899                   Charming old berlin style 111qm  6124361
# 997  1118955                 cosy design flat with home cinema  6140794
# 998  1119402                  Beautiful Berlin flat with flair  6142515
#
#           host_name     neighbourhood_group             neighbourhood  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object
